# %% [markdown]
# <a href="https://colab.research.google.com/github/danielquincy/Python-Data-Science-Practice-/blob/main/ModeloRegresivo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("../data_2.csv")
df
# Out:
#    1000  20000
# 0  1500  21000
# 1  2000  22000
# 2  2500  23000
# 3  3000  24000
# 4  3500  25000
# 5  4000  26000
# 6  4500  27000
# 7  5000  28000
# 8  5500  29000

# %%
plt.xlabel('Area(sqr ft)')
plt.ylabel('Price(US Dollars)')
plt.scatter(df.area, df.precio, color='red',marker='+')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-609229eaaae2> in <cell line: 0>()
#       1 plt.xlabel('Area(sqr ft)')
#       2 plt.ylabel('Price(US Dollars)')
# ----> 3 plt.scatter(df.area, df.precio, color='red',marker='+')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'area'

# %%
reg = LinearRegression()
reg.fit(df[['area']], df.precio)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([67919.67527272])
